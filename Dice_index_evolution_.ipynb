# %% [markdown]
# <a href="https://colab.research.google.com/github/Tizi-94/TEST/blob/master/Dice_index_evolution_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt

# Data points
number_of_images = [2, 4, 8, 16, 32, 65]
#dice_index_b3d = [0.8292162873598504, 0.7496580081093523, 0.8878475694122515, 0.9074998415870354, 0.9064258692946444, 0.9174153059005076]
dice_index_b3d = [0.8292162873598504, 0.8168454898149651 , 0.894424224323054 , 0.9074998415870354, 0.9064258692946444, 0.9174153059005076]
dice_index_nnunet = [0.8514884202275509, 0.8190411636834084, 0.8557852688881589, 0.8917014246841567, 0.9098584498302162, 0.9084964177565906]

# Create the plot
plt.plot(number_of_images, dice_index_nnunet, marker='*', linestyle='-', label='nnUNet')
plt.plot(number_of_images, dice_index_b3d, marker='+', linestyle='-', label='Biom3D')

# Add labels and title
plt.xlabel("Number of Images")
plt.ylabel("Dice Index")
plt.title("Evolution of the Dice Index According to the Number of Images ")

# Add legend
plt.legend()

# Show the plot
plt.grid(True)
plt.show()
